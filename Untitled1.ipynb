# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkurSatyarthi/-Coffee-Prices-Historical-Data-Analysis-and-Predictions/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !conda install numpy pandas matplotlib
# Out:
# /bin/bash: line 1: conda: command not found

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = https://github.com/AnkurSatyarthi/United-State-Ecommerce-record-2020-Data-and-Business-Analysis-and-Prediction-and-Strategic-Reports/blob/main/US%20E-commerce%20records%202020.csv
us = pd.read_html("/content/US E-commerce records 2020.csv")
us
# Out:
#   File "/tmp/ipython-input-1812382138.py", line 1
#     url = https://github.com/AnkurSatyarthi/United-State-Ecommerce-record-2020-Data-and-Business-Analysis-and-Prediction-and-Strategic-Reports/blob/main/US%20E-commerce%20records%202020.csv
#                                                                                                                                                                ^
# SyntaxError: invalid decimal literal

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/AnkurSatyarthi/United-State-Ecommerce-record-2020-Data-and-Business-Analysis-and-Prediction-and-Strategic-Reports
# Out:
# Cloning into 'United-State-Ecommerce-record-2020-Data-and-Business-Analysis-and-Prediction-and-Strategic-Reports'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 32 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 169.54 KiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
